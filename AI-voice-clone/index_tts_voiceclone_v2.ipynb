# %%
## Place requirements.txt and HF_model_downloader.py in /content/
## Then run the cells

# %%
# Clone the repository
# !git clone https://github.com/FurkanGozukara/index-tts
# %cd index-tts

# Update the repository
# !git reset --hard
# !git pull

# Install dependencies
# Create a new Python 3.10 virtual environment
# !python3.10 -m venv venv

# Activate the virtual environment and install dependencies
# This single command ensures all installations are in the correct environment.
# !/bin/bash -c "source ./venv/bin/activate && pip install --upgrade pip && pip install -r requirements.txt"

print('All installed successfully!')
# Out:
# Cloning into 'index-tts'...
# remote: Enumerating objects: 1210, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 1210 (delta 41), reused 35 (delta 35), pack-reused 1146 (from 2)
# Receiving objects: 100% (1210/1210), 33.63 MiB | 15.14 MiB/s, done.
# Resolving deltas: 100% (605/605), done.
# ...
# Error downloading object: examples/emo_hate.wav (89e6e7e): Smudge error: Error downloading examples/emo_hate.wav (89e6e7eee1a28303776e9cf43971e9505529bd0e669f5fcf47f4d1370f9187c4): batch response: This repository exceeded its LFS budget. The account responsible for the budget should increase it to restore access.
#
# Errors logged to /content/index-tts/.git/lfs/logs/20250924T092925.513186297.log
# Use `git lfs logs last` to view the log.
# error: external filter 'git-lfs filter-process' failed
# fatal: examples/emo_hate.wav: smudge filter lfs failed
# ...
# You can inspect what was checked out with 'git status'
# ...

# %%
# %cd /content/
# !python3 HF_model_downloader.py
# Out:
# /content
#
# ...
# Description: Index TTS model from Index_TTS2 subfolder
# [DEBUG] Cache files will be saved in: /content
# [DEBUG] SHA256 cache: /content/sha256_cache.json
# [DEBUG] Verified cache: /content/verified_files_cache.json
# [DEBUG] Current working directory: /content
#
# Repository: MonsterMMORPG/Wan_GGUF
# Subfolder: Index_TTS2
# Target: /content/index-tts/checkpoints
#
# Total files: 20
# Already downloaded: 1
#   ✓ Index_TTS2/config.yaml
# To download: 19
#
# [1/19]
# [INFO] .gitattributes is compressed, downloading without size info
# [DOWNLOADING] .gitattributes (unknown size)
# [OK] .gitattributes completed (1.7 KB) in 0s - Avg: 1.6 MB/s
#
# [2/19]
# [INFO] README.md is compressed, downloading without size info
# [DOWNLOADING] README.md (unknown size)
# [OK] README.md completed (2.4 KB) in 0s - Avg: 2.4 MB/s
#
# [3/19]
# [INFO] Expected SHA256: b2a5ce8090d32da3...
# [DOWNLOADING] bpe.model (464.8 KB)
# [OK] bpe.model completed
# ...

# %%
# Change to the correct directory to run the application
# %cd /content/index-tts

# Run the web UI using the correct Python executable
# !/content/index-tts/venv/bin/python webui.py --share
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.2
#     Uninstalling pip-22.0.2:
#       Successfully uninstalled pip-22.0.2
# ...
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu129
# Ignoring flash_attn: markers 'sys_platform == "win32"' don't match your environment
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.0/256.0 MB 64.3 MB/s  0:00:03
# Ignoring xformers: markers 'sys_platform == "win32"' don't match your environment
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.1/36.1 MB 153.6 MB/s  0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 136.7 MB/s  0:00:00
# Ignoring sageattention: markers 'sys_platform == "win32"' don't match your environment
# Ignoring triton-windows: markers 'sys_platform == "win32"' don't match your environment
# Ignoring wetext: markers 'sys_platform != "linux"' don't match your environment
# ...
